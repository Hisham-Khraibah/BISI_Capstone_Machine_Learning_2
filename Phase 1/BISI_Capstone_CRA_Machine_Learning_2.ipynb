# %% [markdown]
# # BISI_Capstone_Machine_Learning_2
#
# ## Group Members:
# - **Fritzmokake Mwambo**
# - **Hisham Khraibah**
# - **Jinchuan Liu**
# - **Youssra Ibrahim**

# %% [markdown]
# <h1 align='center' style='font-size: 3em; padding: 5px; border-radius: 5px;'>
#   Credit Card Approval Prediction
# </h1>

# %% [markdown]
# # I. **Business Understanding**
# The primary objective of this project is to identify and analyze the key factors that influence an applicant’s credit score and credit card approval outcome. Using historical customer data, the project examines how variables such as income level, employment status, age, credit history, existing debt, and payment behavior affect an applicant’s likelihood of being approved for a credit card.
#
# #### **1.1. Research Questions**
# This project seeks to answer the following research questions:<br>
# &nbsp;&nbsp;&nbsp;&nbsp;**1) Can applicant demographic and financial attributes be used to accurately predict the likelihood of credit card approval?**<br>
# &nbsp;&nbsp;&nbsp;&nbsp;**2) Which applicant features have the strongest influence on credit card approval decisions?**
#
# #### **1.2. Problem Significance**
# The client requires a data-driven approach to assess credit card applications more consistently and accurately. The challenge is to determine which applicants are more likely to be approved based on available demographic and financial information.

# %% [markdown]
# # II. **Data Understanding**

# %% [markdown]
# ### 1. Collect initial data:
# - **Read and load data from CSV file**
# - **Verify the data loaded correctly**
# - **Display the data info**

# %% [markdown]
# | Column | Description |
# |--------|------------|
# | ID | Unique applicant identification number |
# | CODE_GENDER | Applicant gender code (M = Male, F = Female) |
# | FLAG_OWN_CAR | Indicates whether the applicant owns a car (Y/N) |
# | FLAG_OWN_REALTY | Indicates whether the applicant owns real estate (Y/N) |
# | CNT_CHILDREN | Number of children the applicant has |
# | AMT_INCOME_TOTAL | Total annual income of the applicant |
# | NAME_INCOME_TYPE | Type of income source |
# | NAME_EDUCATION_TYPE | Highest education level attained by the applicant |
# | NAME_FAMILY_STATUS | Applicant marital status |
# | NAME_HOUSING_TYPE | Applicant housing type |
# | BIRTHDAY | Applicant date of birth |
# | EMPLOYED_DATE | Date when the applicant started current employment |
# | FLAG_MOBIL | Indicates whether the applicant has a mobile phone (1 = Yes, 0 = No) |
# | FLAG_WORK_PHONE | Indicates whether the applicant has a work phone (1 = Yes, 0 = No) |
# | FLAG_PHONE | Indicates whether the applicant has a home phone (1 = Yes, 0 = No) |
# | FLAG_EMAIL | Indicates whether the applicant has an email address (1 = Yes, 0 = No) |
# | OCCUPATION_TYPE | Applicant occupation category |
# | CNT_FAM_MEMBERS | Total number of family members in the household |
# | SCORE | Credit score assigned to the applicant |

# %% [markdown]
# <br>

# %%
# Pandas for Data Manipulation
import pandas as pd

# Matplotlib for visualization
import matplotlib.pyplot as plt

# Display plots in the notebook
# %matplotlib inline

# Seaborn for easier visualization
import seaborn as sns

# %%
# Adjust the display options to ensure all columns and rows are fully visible during data inspection
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Load 'AC_Capstone_topic_2.csv' in a pandas dataframe 'df'
df = pd.read_csv('AC_Capstone_topic_2.csv')

# %% [markdown]
# <br>

# %% [markdown]
# #### **Observation regarding `df.head()` , `df.tail()` , `df.sample(5)`**
# - **`df.head()`** and **`df.tail()`** are used to preview the beginning and end of our dataset to verify data integrity and structure.
# - The last few rows of the dataset show valid and consistent values, with no signs of corrupted or malformed data at the end of the file.
# - **`df.sample(5)`** are random samples were also inspected to ensure data consistency across the dataset.
# - Our inspection of the dataset suggests that the columns and values make sense, also, missing data is limited.

# %%
# Present the first 5 rows of data
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE   BIRTHDAY EMPLOYED_DATE  \
# 0        Civil marriage   Rented apartment   3/2/1993      8/7/2013
# 1        Civil marriage   Rented apartment   3/2/1993      8/7/2013
# 2               Married  House / apartment  3/30/1967     12/6/2022
# 3  Single / not married  House / apartment  9/18/1973      9/6/2017
# 4  Single / not married  House / apartment  9/18/1973      9/6/2017
#
#    FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0           1                1           0           0             NaN
# 1           1                1           0           0             NaN
# 2           1                0           0           0  Security staff
# 3           1                0           1           1     Sales staff
# 4           1                0           1           1     Sales staff
#
#    CNT_FAM_MEMBERS  SCORE
# 0                2   9367
# 1                2   9325
# 2                2   9698
# 3                1   9482
# 4                1  10000

# %%
# Present the last 5 rows of data
df.tail()
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 36452  5149828           M            Y               Y             0
# 36453  5149834           F            N               Y             0
# 36454  5149838           F            N               Y             0
# 36455  5150049           F            N               Y             0
# 36456  5150337           M            N               Y             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 36452          315000.0               Working  Secondary / secondary special
# 36453          157500.0  Commercial associate               Higher education
# 36454          157500.0             Pensioner               Higher education
# 36455          283500.0               Working  Secondary / secondary special
# 36456          112500.0               Working  Secondary / secondary special
#
#          NAME_FAMILY_STATUS  NAME_HOUSING_TYPE    BIRTHDAY EMPLOYED_DATE  \
# 36452               Married  House / apartment   7/16/1978     5/30/2019
# 36453               Married  House / apartment   2/14/1992     5/29/2022
# 36454               Married  House / apartment   2/14/1992     5/29/2022
# 36455               Married  House / apartment  11/13/1976     3/29/2024
# 36456  Single / not married   Rented apartment  11/17/2000     10/8/2022
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 36452           1                0           0           0        Managers
# 36453           1                0           1           1  Medicine staff
# 36454           1                0           1           1  Medicine staff
# 36455           1                0           0           0     Sales staff
# 36456           1                0           0           0        Laborers
#
#        CNT_FAM_MEMBERS  SCORE
# 36452                2   6682
# 36453                2   2815
# 36454                2   4774
# 36455                2   7095
# 36456                1   7555

# %%
# Present a random sample of 5 rows from the dataset
df.sample(5)
# Out:
#             ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 29948  5118534           F            Y               Y             0
# 33337  5142453           M            Y               Y             0
# 25524  5105207           F            N               Y             0
# 15121  5061781           F            N               Y             0
# 35204  5149086           F            N               Y             0
#
#        AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 29948          225000.0  Commercial associate  Secondary / secondary special
# 33337          315000.0               Working              Incomplete higher
# 25524          126000.0             Pensioner  Secondary / secondary special
# 15121          157500.0             Pensioner  Secondary / secondary special
# 35204           76500.0               Working  Secondary / secondary special
#
#       NAME_FAMILY_STATUS  NAME_HOUSING_TYPE    BIRTHDAY EMPLOYED_DATE  \
# 29948            Married  House / apartment   9/18/1965    10/10/2023
# 33337            Married  House / apartment  11/11/1996     1/30/2022
# 25524          Separated  House / apartment   6/30/1966           NaN
# 15121          Separated  House / apartment   5/28/1968           NaN
# 35204            Married  House / apartment   4/12/1981     1/27/2021
#
#        FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 29948           1                0           0           0        Laborers
# 33337           1                0           0           0        Managers
# 25524           1                0           0           0             NaN
# 15121           1                0           0           0             NaN
# 35204           1                0           0           0     Sales staff
#
#        CNT_FAM_MEMBERS  SCORE
# 29948                2   9353
# 33337                2  10000
# 25524                1   9402
# 15121                1  10000
# 35204                2   9765

# %% [markdown]
# <br>

# %% [markdown]
# #### **Observation regarding `df.shape`**
# - **The dataset contains `36457` observations and `19` variables, indicating an adequate size for machine learning analysis.**

# %%
# Dataset dimensions
df.shape
# Out:
# (36457, 19)

# %% [markdown]
# <br>

# %% [markdown]
# #### **Observation regarding `df.info()`**
# - **The dataset contains a mix of numerical and categorical variables, so that categorical features will require encoding before modeling.**
# - **Missing values are present in `EMPLOYED_DATE` and `OCCUPATION_TYPE`, so we also need to clean the data before modeling.**

# %%
# Check dataset information and missing values
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 36457 entries, 0 to 36456
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   36457 non-null  int64
#  1   CODE_GENDER          36457 non-null  str
#  2   FLAG_OWN_CAR         36457 non-null  str
#  3   FLAG_OWN_REALTY      36457 non-null  str
#  4   CNT_CHILDREN         36457 non-null  int64
#  5   AMT_INCOME_TOTAL     36457 non-null  float64
#  6   NAME_INCOME_TYPE     36457 non-null  str
#  7   NAME_EDUCATION_TYPE  36457 non-null  str
#  8   NAME_FAMILY_STATUS   36457 non-null  str
#  9   NAME_HOUSING_TYPE    36457 non-null  str
#  10  BIRTHDAY             36457 non-null  str
#  11  EMPLOYED_DATE        30322 non-null  str
#  12  FLAG_MOBIL           36457 non-null  int64
#  13  FLAG_WORK_PHONE      36457 non-null  int64
#  14  FLAG_PHONE           36457 non-null  int64
#  15  FLAG_EMAIL           36457 non-null  int64
#  16  OCCUPATION_TYPE      25134 non-null  str
#  17  CNT_FAM_MEMBERS      36457 non-null  int64
#  18  SCORE                36457 non-null  int64
# dtypes: float64(1), int64(8), str(10)
# memory usage: 8.4 MB

# %% [markdown]
# <br>

# %% [markdown]
# #### **Observation regarding `df_columns`**
# - **The dataset contains `9` numerical columns:
# `ID`, `CNT_CHILDREN`, `AMT_INCOME_TOTAL`, `FLAG_MOBIL`, `FLAG_WORK_PHONE`, `FLAG_PHONE`, `FLAG_EMAIL`, `CNT_FAM_MEMBERS`, and `SCORE`.**
# - **The numerical features include continuous variables, count variables, and binary indicator variables.**

# %%
numeric_df = df._get_numeric_data()
df_columns = numeric_df.columns

# %%
df_columns
# Out:
# Index(['ID', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'FLAG_MOBIL',
#        'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL', 'CNT_FAM_MEMBERS',
#        'SCORE'],
#       dtype='str')

# %% [markdown]
# <br>

# %% [markdown]
# #### **Observation regarding `df.describe()`**
# - Income and credit score show substantial variation across individuals based on the relatively large standard deviations, suggesting good diversity in financial profiles.
# - Most applicants have zero or one child, and the median family size is two members, indicating relatively small households.
# - Binary flag variables (mobile phone, work phone, phone, email) are properly bounded between 0 and 1, with mobile phone ownership being nearly universal.
# - Overall, the numerical variables appear reasonable with no obvious anomalies based on this summary.

# %%
# Check analytical summ<br>ary of the dataset
df.describe()
# Out:
#                  ID  CNT_CHILDREN  AMT_INCOME_TOTAL  FLAG_MOBIL  \
# count  3.645700e+04  36457.000000      3.645700e+04     36457.0
# mean   5.078227e+06      0.430315      1.866857e+05         1.0
# std    4.187524e+04      0.742367      1.017892e+05         0.0
# min    5.008804e+06      0.000000      2.700000e+04         1.0
# 25%    5.042028e+06      0.000000      1.215000e+05         1.0
# 50%    5.074614e+06      0.000000      1.575000e+05         1.0
# 75%    5.115396e+06      1.000000      2.250000e+05         1.0
# max    5.150487e+06     19.000000      1.575000e+06         1.0
#
#        FLAG_WORK_PHONE    FLAG_PHONE    FLAG_EMAIL  CNT_FAM_MEMBERS  \
# count     36457.000000  36457.000000  36457.000000     36457.000000
# mean          0.225526      0.294813      0.089722         2.198453
# std           0.417934      0.455965      0.285787         0.911686
# min           0.000000      0.000000      0.000000         1.000000
# 25%           0.000000      0.000000      0.000000         2.000000
# 50%           0.000000      0.000000      0.000000         2.000000
# 75%           0.000000      1.000000      0.000000         3.000000
# max           1.000000      1.000000      1.000000        20.000000
#
#               SCORE
# count  36457.000000
# mean    9246.663329
# std      741.150612
# min      316.000000
# 25%     8835.000000
# 50%     9353.000000
# 75%     9771.000000
# max    10000.000000

# %% [markdown]
# <br>

# %% [markdown]
# #### **Observation regarding `sns.pairplot(df)` | (Pre-check)**
# - The dataset contains a high number of **binary features**, which appear as vertical and horizontal bands in the pairwise plots.
# - Continuous variables display **weak pairwise linear relationships**, with no clearly defined linear trends across feature combinations.
# - Several numerical features, including `AMT_INCOME_TOTAL` and `SCORE`, show **right-skewed distributions** in the diagonal plots.
# - Count-based variables such as `CNT_CHILDREN` and `CNT_FAM_MEMBERS` take **discrete integer values**, resulting in visible clustering patterns.
# - The relationship between `AMT_INCOME_TOTAL` and `SCORE` appears scattered and non-linear, with no clear monotonic pattern.
# - Binary flag variables exhibit **uneven class distributions**, as indicated by imbalanced histogram bars.
# - No strong pairwise feature dependency or multicollinearity is visually apparent from the pairplot.

# %%
# Plot pairwise relationships using seaborn pairplot
sns.pairplot(df)
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# #### **Observation regarding `SCORE`| (Pre-check)**
# - The `SCORE` variable shows a **non-uniform** distribution with most values concentrated in the higher score range.
# - The distribution is **left-skewed**, with a long tail extending toward lower score values.
# - Multiple peaks are visible, indicating that the `SCORE` values are **clustered around specific ranges** rather than being smoothly distributed.
# - Very low score values occur **infrequently** compared to high score values.

# %%
# Plot the distribution of the credit score to examine its spread, skewness, and overall shape
sns.histplot(df['SCORE'], kde=True)
plt.title('Distribution of Credit Score')
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# #### **Observation regarding missing values (Pre-check)**
# - `OCCUPATION_TYPE` and `EMPLOYED_DATE` contain a noticeable amount of missing data.

# %%
# Check missing values
missing_values = df.isnull().sum()

# Calculate missing value percentages
missing_percentage = (missing_values / len(df)) * 100

# Display missing value summary
missing_df = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage (%)': missing_percentage
}).sort_values(by='Missing Values', ascending=False)

print(missing_df)
# Out:
#                      Missing Values  Percentage (%)
# OCCUPATION_TYPE               11323       31.058507
# EMPLOYED_DATE                  6135       16.828044
# ID                                0        0.000000
# FLAG_OWN_CAR                      0        0.000000
# CODE_GENDER                       0        0.000000
# FLAG_OWN_REALTY                   0        0.000000
# CNT_CHILDREN                      0        0.000000
# NAME_EDUCATION_TYPE               0        0.000000
# NAME_FAMILY_STATUS                0        0.000000
# AMT_INCOME_TOTAL                  0        0.000000
# NAME_INCOME_TYPE                  0        0.000000
# BIRTHDAY                          0        0.000000
# NAME_HOUSING_TYPE                 0        0.000000
# FLAG_WORK_PHONE                   0        0.000000
# FLAG_MOBIL                        0        0.000000
# FLAG_PHONE                        0        0.000000
# FLAG_EMAIL                        0        0.000000
# CNT_FAM_MEMBERS                   0        0.000000
# SCORE                             0        0.000000

# %% [markdown]
# <br>

# %% [markdown]
# #### **Observation regarding the `duplicated`**
# - The `ID` column is removed to avoid using a unique identifier in duplicate detection.
# - The output highlights rows that are **exact duplicates across all remaining columns**.

# %%
# Remove the ID column
df = df.drop(columns=['ID'])

# %%
# Identify duplicate rows
duplicates = df.duplicated()

# %%
# Display duplicate records
duplicates[duplicates==True]
# Out:
# 8        True
# 9        True
# 15       True
# 26       True
# 35       True
# 37       True
# 38       True
# 39       True
# 43       True
# 46       True
# 48       True
# 50       True
# 51       True
# 52       True
# 53       True
# 55       True
# 57       True
# 65       True
# 68       True
# 72       True
# 73       True
# 77       True
# 78       True
# 79       True
# 80       True
# 81       True
# 82       True
# 83       True
# 84       True
# 86       True
# 87       True
# 88       True
# 89       True
# 90       True
# 91       True
# 92       True
# 93       True
# 94       True
# 95       True
# 96       True
# 98       True
# 100      True
# 102      True
# 107      True
# 108      True
# 112      True
# 116      True
# 117      True
# 119      True
# 121      True
# 122      True
# 123      True
# 124      True
# 127      True
# 128      True
# 129      True
# 131      True
# 132      True
# 133      True
# 136      True
# 140      True
# 141      True
# 149      True
# 153      True
# 154      True
# 158      True
# 159      True
# 160      True
# 162      True
# 170      True
# 173      True
# 174      True
# 176      True
# 177      True
# 178      True
# 179      True
# 181      True
# 195      True
# 207      True
# 213      True
# 216      True
# 222      True
# 227      True
# 243      True
# 251      True
# 252      True
# 259      True
# 260      True
# 261      True
# 263      True
# 265      True
# 267      True
# 269      True
# 270      True
# 275      True
# 278      True
# 290      True
# 294      True
# 299      True
# 301      True
# 302      True
# 303      True
# 304      True
# 318      True
# 327      True
# 328      True
# 331      True
# 346      True
# 347      True
# 361      True
# 393      True
# 419      True
# 421      True
# 425      True
# 427      True
# 432      True
# 436      True
# 451      True
# 458      True
# 459      True
# 463      True
# 479      True
# 486      True
# 488      True
# 501      True
# 503      True
# 509      True
# 510      True
# 511      True
# 521      True
# 555      True
# 573      True
# 575      True
# 592      True
# 593      True
# 601      True
# 603      True
# 604      True
# 605      True
# 607      True
# 608      True
# 609      True
# 615      True
# 619      True
# 630      True
# 634      True
# 640      True
# 641      True
# 642      True
# 643      True
# 667      True
# 673      True
# 681      True
# 683      True
# 693      True
# 700      True
# 703      True
# 710      True
# 722      True
# 726      True
# 738      True
# 742      True
# 763      True
# 767      True
# 768      True
# 769      True
# 771      True
# 774      True
# 781      True
# 784      True
# 786      True
# 792      True
# 793      True
# 795      True
# 796      True
# 797      True
# 798      True
# 799      True
# 801      True
# 802      True
# 805      True
# 806      True
# 807      True
# 813      True
# 814      True
# 822      True
# 845      True
# 850      True
# 855      True
# 859      True
# 862      True
# 890      True
# 892      True
# 898      True
# 899      True
# 904      True
# 932      True
# 934      True
# 938      True
# 951      True
# 952      True
# 953      True
# 955      True
# 956      True
# 967      True
# 975      True
# 977      True
# 980      True
# 991      True
# 992      True
# 1021     True
# 1024     True
# 1026     True
# 1027     True
# 1040     True
# 1054     True
# 1057     True
# 1060     True
# 1061     True
# 1062     True
# 1063     True
# 1083     True
# 1086     True
# 1089     True
# 1099     True
# 1100     True
# 1102     True
# 1106     True
# 1135     True
# 1136     True
# 1137     True
# 1155     True
# 1157     True
# 1160     True
# 1161     True
# 1164     True
# 1165     True
# 1169     True
# 1170     True
# 1171     True
# 1172     True
# 1173     True
# 1174     True
# 1175     True
# 1176     True
# 1177     True
# 1184     True
# 1191     True
# 1193     True
# 1197     True
# 1199     True
# 1216     True
# 1223     True
# 1227     True
# 1228     True
# 1230     True
# 1233     True
# 1249     True
# 1254     True
# 1263     True
# 1266     True
# 1267     True
# 1270     True
# 1277     True
# 1278     True
# 1280     True
# 1284     True
# 1290     True
# 1294     True
# 1295     True
# 1312     True
# 1339     True
# 1340     True
# 1342     True
# 1343     True
# 1358     True
# 1363     True
# 1364     True
# 1368     True
# 1371     True
# 1372     True
# 1376     True
# 1377     True
# 1385     True
# 1386     True
# 1390     True
# 1391     True
# 1394     True
# 1395     True
# 1396     True
# 1399     True
# 1407     True
# 1409     True
# 1410     True
# 1428     True
# 1443     True
# 1444     True
# 1456     True
# 1457     True
# 1472     True
# 1476     True
# 1477     True
# 1486     True
# 1487     True
# 1494     True
# 1508     True
# 1511     True
# 1517     True
# 1518     True
# 1521     True
# 1523     True
# 1524     True
# 1528     True
# 1534     True
# 1539     True
# 1541     True
# 1544     True
# 1547     True
# 1548     True
# 1551     True
# 1560     True
# 1566     True
# 1570     True
# 1572     True
# 1573     True
# 1574     True
# 1577     True
# 1581     True
# 1585     True
# 1589     True
# 1593     True
# 1599     True
# 1603     True
# 1604     True
# 1605     True
# 1606     True
# 1607     True
# 1608     True
# 1609     True
# 1612     True
# 1621     True
# 1623     True
# 1624     True
# 1625     True
# 1627     True
# 1628     True
# 1639     True
# 1654     True
# 1681     True
# 1682     True
# 1689     True
# 1694     True
# 1695     True
# 1696     True
# 1699     True
# 1700     True
# 1710     True
# 1715     True
# 1719     True
# 1720     True
# 1725     True
# 1732     True
# 1733     True
# 1734     True
# 1738     True
# 1740     True
# 1744     True
# 1759     True
# 1760     True
# 1764     True
# 1767     True
# 1770     True
# 1789     True
# 1791     True
# 1793     True
# 1815     True
# 1816     True
# 1825     True
# 1828     True
# 1830     True
# 1831     True
# 1836     True
# 1837     True
# 1839     True
# 1840     True
# 1850     True
# 1865     True
# 1877     True
# 1878     True
# 1880     True
# 1881     True
# 1882     True
# 1885     True
# 1897     True
# 1900     True
# 1901     True
# 1902     True
# 1910     True
# 1912     True
# 1913     True
# 1914     True
# 1915     True
# 1917     True
# 1918     True
# 1919     True
# 1920     True
# 1925     True
# 1926     True
# 1930     True
# 1942     True
# 1946     True
# 1948     True
# 1958     True
# 1961     True
# 1962     True
# 1965     True
# 1966     True
# 1968     True
# 1969     True
# 1970     True
# 1971     True
# 1972     True
# 1975     True
# 1976     True
# 1977     True
# 1978     True
# 1980     True
# 1981     True
# 1987     True
# 1988     True
# 2027     True
# 2032     True
# 2035     True
# 2037     True
# 2038     True
# 2047     True
# 2048     True
# 2054     True
# 2056     True
# 2062     True
# 2068     True
# 2069     True
# 2070     True
# 2072     True
# 2073     True
# 2111     True
# 2112     True
# 2121     True
# 2123     True
# 2135     True
# 2137     True
# 2138     True
# 2140     True
# 2145     True
# 2146     True
# 2159     True
# 2160     True
# 2164     True
# 2176     True
# 2177     True
# 2178     True
# 2180     True
# 2184     True
# 2189     True
# 2190     True
# 2191     True
# 2202     True
# 2217     True
# 2218     True
# 2219     True
# 2220     True
# 2221     True
# 2231     True
# 2238     True
# 2247     True
# 2249     True
# 2251     True
# 2255     True
# 2256     True
# 2258     True
# 2259     True
# 2260     True
# 2261     True
# 2264     True
# 2265     True
# 2268     True
# 2269     True
# 2271     True
# 2272     True
# 2276     True
# 2282     True
# 2284     True
# 2288     True
# 2294     True
# 2296     True
# 2301     True
# 2312     True
# 2313     True
# 2315     True
# 2317     True
# 2322     True
# 2324     True
# 2328     True
# 2330     True
# 2332     True
# 2333     True
# 2335     True
# 2340     True
# 2345     True
# 2346     True
# 2348     True
# 2371     True
# 2375     True
# 2382     True
# 2385     True
# 2387     True
# 2388     True
# 2395     True
# 2397     True
# 2398     True
# 2400     True
# 2401     True
# 2407     True
# 2414     True
# 2415     True
# 2418     True
# 2419     True
# 2439     True
# 2443     True
# 2448     True
# 2452     True
# 2453     True
# 2455     True
# 2456     True
# 2458     True
# 2459     True
# 2460     True
# 2468     True
# 2471     True
# 2483     True
# 2486     True
# 2493     True
# 2516     True
# 2521     True
# 2526     True
# 2535     True
# 2536     True
# 2537     True
# 2547     True
# 2548     True
# 2549     True
# 2553     True
# 2556     True
# 2559     True
# 2560     True
# 2562     True
# 2566     True
# 2568     True
# 2569     True
# 2597     True
# 2598     True
# 2614     True
# 2619     True
# 2620     True
# 2630     True
# 2633     True
# 2635     True
# 2639     True
# 2644     True
# 2645     True
# 2646     True
# 2648     True
# 2652     True
# 2688     True
# 2689     True
# 2692     True
# 2693     True
# 2696     True
# 2703     True
# 2724     True
# 2735     True
# 2738     True
# 2748     True
# 2751     True
# 2753     True
# 2757     True
# 2758     True
# 2760     True
# 2761     True
# 2762     True
# 2776     True
# 2777     True
# 2812     True
# 2813     True
# 2815     True
# 2817     True
# 2819     True
# 2820     True
# 2821     True
# 2831     True
# 2832     True
# 2838     True
# 2844     True
# 2845     True
# 2853     True
# 2854     True
# 2856     True
# 2858     True
# 2859     True
# 2866     True
# 2868     True
# 2869     True
# 2870     True
# 2871     True
# 2878     True
# 2887     True
# 2892     True
# 2903     True
# 2904     True
# 2909     True
# 2910     True
# 2911     True
# 2922     True
# 2935     True
# 2938     True
# 2939     True
# 2955     True
# 2956     True
# 2957     True
# 2962     True
# 2963     True
# 2964     True
# 2976     True
# 2982     True
# 2995     True
# 2997     True
# 3000     True
# 3009     True
# 3010     True
# 3011     True
# 3022     True
# 3025     True
# 3027     True
# 3028     True
# 3039     True
# 3042     True
# 3045     True
# 3047     True
# 3049     True
# 3050     True
# 3055     True
# 3056     True
# 3057     True
# 3058     True
# 3061     True
# 3062     True
# 3063     True
# 3066     True
# 3074     True
# 3081     True
# 3082     True
# 3083     True
# 3084     True
# 3085     True
# 3086     True
# 3087     True
# 3089     True
# 3110     True
# 3117     True
# 3118     True
# 3119     True
# 3120     True
# 3124     True
# 3125     True
# 3130     True
# 3131     True
# 3134     True
# 3137     True
# 3140     True
# 3141     True
# 3146     True
# 3147     True
# 3150     True
# 3151     True
# 3152     True
# 3153     True
# 3158     True
# 3160     True
# 3161     True
# 3163     True
# 3175     True
# 3190     True
# 3193     True
# 3195     True
# 3198     True
# 3200     True
# 3201     True
# 3204     True
# 3205     True
# 3209     True
# 3216     True
# 3217     True
# 3219     True
# 3220     True
# 3239     True
# 3244     True
# 3257     True
# 3267     True
# 3268     True
# 3272     True
# 3275     True
# 3277     True
# 3286     True
# 3287     True
# 3288     True
# 3293     True
# 3307     True
# 3309     True
# 3311     True
# 3312     True
# 3320     True
# 3328     True
# 3329     True
# 3330     True
# 3336     True
# 3338     True
# 3339     True
# 3340     True
# 3344     True
# 3345     True
# 3347     True
# 3348     True
# 3354     True
# 3355     True
# 3357     True
# 3365     True
# 3381     True
# 3385     True
# 3389     True
# 3394     True
# 3400     True
# 3401     True
# 3405     True
# 3414     True
# 3416     True
# 3419     True
# 3425     True
# 3426     True
# 3427     True
# 3428     True
# 3443     True
# 3447     True
# 3449     True
# 3455     True
# 3456     True
# 3457     True
# 3458     True
# 3459     True
# 3460     True
# 3461     True
# 3462     True
# 3463     True
# 3469     True
# 3473     True
# 3475     True
# 3477     True
# 3486     True
# 3503     True
# 3507     True
# 3508     True
# 3511     True
# 3514     True
# 3515     True
# 3525     True
# 3527     True
# 3528     True
# 3538     True
# 3540     True
# 3541     True
# 3544     True
# 3546     True
# 3548     True
# 3549     True
# 3551     True
# 3553     True
# 3563     True
# 3570     True
# 3574     True
# 3575     True
# 3585     True
# 3586     True
# 3594     True
# 3601     True
# 3604     True
# 3605     True
# 3607     True
# 3611     True
# 3614     True
# 3615     True
# 3618     True
# 3620     True
# 3623     True
# 3626     True
# 3629     True
# 3631     True
# 3638     True
# 3639     True
# 3641     True
# 3642     True
# 3643     True
# 3644     True
# 3645     True
# 3650     True
# 3655     True
# 3657     True
# 3658     True
# 3665     True
# 3666     True
# 3676     True
# 3683     True
# 3692     True
# 3695     True
# 3697     True
# 3698     True
# 3701     True
# 3702     True
# 3704     True
# 3705     True
# 3706     True
# 3707     True
# 3708     True
# 3709     True
# 3710     True
# 3711     True
# 3721     True
# 3722     True
# 3723     True
# 3730     True
# 3731     True
# 3732     True
# 3737     True
# 3746     True
# 3753     True
# 3755     True
# 3756     True
# 3759     True
# 3760     True
# 3761     True
# 3769     True
# 3773     True
# 3774     True
# 3783     True
# 3789     True
# 3791     True
# 3795     True
# 3797     True
# 3809     True
# 3813     True
# 3821     True
# 3823     True
# 3828     True
# 3834     True
# 3841     True
# 3842     True
# 3848     True
# 3850     True
# 3857     True
# 3872     True
# 3890     True
# 3900     True
# 3901     True
# 3903     True
# 3904     True
# 3905     True
# 3906     True
# 3914     True
# 3917     True
# 3918     True
# 3919     True
# 3939     True
# 3940     True
# 3941     True
# 3942     True
# 3943     True
# 3944     True
# 3947     True
# 3951     True
# 3952     True
# 3957     True
# 3958     True
# 3990     True
# 3991     True
# 3995     True
# 4001     True
# 4005     True
# 4006     True
# 4009     True
# 4010     True
# 4018     True
# 4020     True
# 4022     True
# 4034     True
# 4041     True
# 4042     True
# 4043     True
# 4044     True
# 4056     True
# 4057     True
# 4064     True
# 4065     True
# 4066     True
# 4068     True
# 4080     True
# 4086     True
# 4087     True
# 4091     True
# 4099     True
# 4100     True
# 4106     True
# 4108     True
# 4109     True
# 4113     True
# 4121     True
# 4134     True
# 4143     True
# 4144     True
# 4145     True
# 4147     True
# 4148     True
# 4149     True
# 4150     True
# 4152     True
# 4171     True
# 4173     True
# 4177     True
# 4182     True
# 4184     True
# 4191     True
# 4192     True
# 4193     True
# 4195     True
# 4197     True
# 4203     True
# 4207     True
# 4208     True
# 4209     True
# 4212     True
# 4214     True
# 4215     True
# 4216     True
# 4217     True
# 4219     True
# 4223     True
# 4229     True
# 4230     True
# 4239     True
# 4240     True
# 4241     True
# 4242     True
# 4244     True
# 4248     True
# 4253     True
# 4255     True
# 4257     True
# 4264     True
# 4267     True
# 4268     True
# 4271     True
# 4272     True
# 4274     True
# 4278     True
# 4279     True
# 4284     True
# 4287     True
# 4288     True
# 4296     True
# 4307     True
# 4323     True
# 4327     True
# 4328     True
# 4335     True
# 4346     True
# 4347     True
# 4349     True
# 4360     True
# 4367     True
# 4368     True
# 4382     True
# 4390     True
# 4391     True
# 4392     True
# 4393     True
# 4400     True
# 4409     True
# 4428     True
# 4433     True
# 4440     True
# 4453     True
# 4457     True
# 4466     True
# 4467     True
# 4470     True
# 4480     True
# 4482     True
# 4486     True
# 4487     True
# 4488     True
# 4489     True
# 4490     True
# 4500     True
# 4503     True
# 4506     True
# 4508     True
# 4524     True
# 4540     True
# 4546     True
# 4548     True
# 4549     True
# 4560     True
# 4563     True
# 4572     True
# 4586     True
# 4591     True
# 4592     True
# 4593     True
# 4594     True
# 4595     True
# 4598     True
# 4613     True
# 4624     True
# 4641     True
# 4649     True
# 4651     True
# 4656     True
# 4662     True
# 4664     True
# 4671     True
# 4689     True
# 4691     True
# 4696     True
# 4702     True
# 4704     True
# 4706     True
# 4710     True
# 4716     True
# 4719     True
# 4723     True
# 4725     True
# 4744     True
# 4746     True
# 4747     True
# 4750     True
# 4752     True
# 4753     True
# 4758     True
# 4762     True
# 4763     True
# 4764     True
# 4767     True
# 4771     True
# 4773     True
# 4774     True
# 4782     True
# 4784     True
# 4787     True
# 4801     True
# 4803     True
# 4805     True
# 4806     True
# 4809     True
# 4856     True
# 5013     True
# 5014     True
# 5062     True
# 5069     True
# 5073     True
# 5074     True
# 5075     True
# 5077     True
# 5078     True
# 5079     True
# 5080     True
# 5081     True
# 5082     True
# 5083     True
# 5084     True
# 5087     True
# 5089     True
# 5091     True
# 5094     True
# 5095     True
# 5096     True
# 5099     True
# 5102     True
# 5103     True
# 5104     True
# 5105     True
# 5107     True
# 5108     True
# 5109     True
# 5110     True
# 5111     True
# 5112     True
# 5113     True
# 5115     True
# 5116     True
# 5118     True
# 5119     True
# 5121     True
# 5122     True
# 5124     True
# 5125     True
# 5126     True
# 5127     True
# 5128     True
# 5129     True
# 5130     True
# 5131     True
# 5135     True
# 5136     True
# 5137     True
# 5138     True
# 5140     True
# 5141     True
# 5142     True
# 5145     True
# 5146     True
# 5147     True
# 5149     True
# 5151     True
# 5152     True
# 5153     True
# 5154     True
# 5155     True
# 5157     True
# 5160     True
# 5161     True
# 5163     True
# 5164     True
# 5165     True
# 5166     True
# 5167     True
# 5168     True
# 5169     True
# 5170     True
# 5171     True
# 5172     True
# 5173     True
# 5174     True
# 5175     True
# 5176     True
# 5177     True
# 5178     True
# 5179     True
# 5180     True
# 5181     True
# 5182     True
# 5183     True
# 5184     True
# 5187     True
# 5188     True
# 5189     True
# 5190     True
# 5191     True
# 5193     True
# 5196     True
# 5197     True
# 5200     True
# 5201     True
# 5202     True
# 5203     True
# 5204     True
# 5205     True
# 5206     True
# 5209     True
# 5210     True
# 5211     True
# 5212     True
# 5213     True
# 5214     True
# 5220     True
# 5221     True
# 5222     True
# 5223     True
# 5224     True
# 5225     True
# 5226     True
# 5233     True
# 5237     True
# 5240     True
# 5241     True
# 5244     True
# 5245     True
# 5246     True
# 5247     True
# 5252     True
# 5253     True
# 5256     True
# 5257     True
# 5258     True
# 5260     True
# 5262     True
# 5263     True
# 5264     True
# 5265     True
# 5267     True
# 5268     True
# 5269     True
# 5270     True
# 5271     True
# 5272     True
# 5273     True
# 5274     True
# 5275     True
# 5276     True
# 5278     True
# 5279     True
# 5280     True
# 5281     True
# 5282     True
# 5283     True
# 5285     True
# 5289     True
# 5290     True
# 5291     True
# 5293     True
# 5295     True
# 5296     True
# 5298     True
# 5299     True
# 5300     True
# 5301     True
# 5302     True
# 5308     True
# 5309     True
# 5310     True
# 5311     True
# 5312     True
# 5313     True
# 5316     True
# 5317     True
# 5319     True
# 5320     True
# 5321     True
# 5322     True
# 5323     True
# 5324     True
# 5326     True
# 5327     True
# 5328     True
# 5334     True
# 5335     True
# 5336     True
# 5337     True
# 5338     True
# 5340     True
# 5341     True
# 5342     True
# 5343     True
# 5344     True
# 5345     True
# 5346     True
# 5348     True
# 5351     True
# 5352     True
# 5357     True
# 5358     True
# 5359     True
# 5360     True
# 5361     True
# 5362     True
# 5363     True
# 5364     True
# 5365     True
# 5366     True
# 5367     True
# 5369     True
# 5370     True
# 5372     True
# 5374     True
# 5375     True
# 5376     True
# 5377     True
# 5378     True
# 5380     True
# 5381     True
# 5385     True
# 5386     True
# 5387     True
# 5389     True
# 5390     True
# 5391     True
# 5392     True
# 5393     True
# 5394     True
# 5395     True
# 5398     True
# 5399     True
# 5400     True
# 5402     True
# 5403     True
# 5404     True
# 5405     True
# 5406     True
# 5407     True
# 5408     True
# 5409     True
# 5411     True
# 5412     True
# 5414     True
# 5415     True
# 5417     True
# 5418     True
# 5419     True
# 5420     True
# 5421     True
# 5422     True
# 5423     True
# 5425     True
# 5426     True
# 5428     True
# 5432     True
# 5433     True
# 5434     True
# 5435     True
# 5437     True
# 5438     True
# 5443     True
# 5444     True
# 5445     True
# 5446     True
# 5447     True
# 5449     True
# 5452     True
# 5453     True
# 5454     True
# 5456     True
# 5458     True
# 5459     True
# 5462     True
# 5463     True
# 5464     True
# 5466     True
# 5467     True
# 5469     True
# 5470     True
# 5471     True
# 5472     True
# 5473     True
# 5474     True
# 5476     True
# 5477     True
# 5478     True
# 5479     True
# 5480     True
# 5481     True
# 5484     True
# 5487     True
# 5488     True
# 5490     True
# 5491     True
# 5492     True
# 5496     True
# 5498     True
# 5499     True
# 5500     True
# 5503     True
# 5504     True
# 5507     True
# 5509     True
# 5510     True
# 5511     True
# 5512     True
# 5513     True
# 5515     True
# 5517     True
# 5525     True
# 5528     True
# 5546     True
# 5556     True
# 5561     True
# 5564     True
# 5565     True
# 5567     True
# 5573     True
# 5575     True
# 5581     True
# 5582     True
# 5583     True
# 5584     True
# 5592     True
# 5599     True
# 5618     True
# 5620     True
# 5623     True
# 5637     True
# 5650     True
# 5651     True
# 5659     True
# 5660     True
# 5661     True
# 5664     True
# 5670     True
# 5675     True
# 5677     True
# 5682     True
# 5691     True
# 5693     True
# 5700     True
# 5712     True
# 5713     True
# 5714     True
# 5715     True
# 5724     True
# 5737     True
# 5739     True
# 5740     True
# 5742     True
# 5752     True
# 5754     True
# 5756     True
# 5757     True
# 5766     True
# 5771     True
# 5772     True
# 5796     True
# 5803     True
# 5815     True
# 5825     True
# 5829     True
# 5830     True
# 5839     True
# 5840     True
# 5841     True
# 5842     True
# 5843     True
# 5844     True
# 5848     True
# 5849     True
# 5853     True
# 5854     True
# 5859     True
# 5867     True
# 5879     True
# 5893     True
# 5898     True
# 5912     True
# 5914     True
# 5915     True
# 5925     True
# 5928     True
# 5931     True
# 5932     True
# 5933     True
# 5934     True
# 5935     True
# 5936     True
# 5939     True
# 5940     True
# 5946     True
# 5947     True
# 5948     True
# 5949     True
# 5950     True
# 5962     True
# 5963     True
# 5965     True
# 5978     True
# 5984     True
# 6013     True
# 6014     True
# 6015     True
# 6017     True
# 6018     True
# 6033     True
# 6042     True
# 6044     True
# 6056     True
# 6059     True
# 6067     True
# 6087     True
# 6091     True
# 6098     True
# 6109     True
# 6113     True
# 6118     True
# 6126     True
# 6136     True
# 6137     True
# 6149     True
# 6167     True
# 6194     True
# 6196     True
# 6206     True
# 6208     True
# 6209     True
# 6211     True
# 6220     True
# 6225     True
# 6278     True
# 6286     True
# 6293     True
# 6298     True
# 6300     True
# 6322     True
# 6323     True
# 6324     True
# 6327     True
# 6338     True
# 6339     True
# 6341     True
# 6342     True
# 6343     True
# 6344     True
# 6347     True
# 6353     True
# 6364     True
# 6389     True
# 6392     True
# 6395     True
# 6398     True
# 6399     True
# 6400     True
# 6402     True
# 6409     True
# 6411     True
# 6414     True
# 6419     True
# 6421     True
# 6423     True
# 6425     True
# 6434     True
# 6435     True
# 6438     True
# 6440     True
# 6441     True
# 6444     True
# 6445     True
# 6446     True
# 6450     True
# 6451     True
# 6455     True
# 6461     True
# 6486     True
# 6490     True
# 6499     True
# 6500     True
# 6503     True
# 6506     True
# 6512     True
# 6514     True
# 6515     True
# 6517     True
# 6519     True
# 6523     True
# 6529     True
# 6543     True
# 6544     True
# 6546     True
# 6548     True
# 6549     True
# 6559     True
# 6567     True
# 6569     True
# 6573     True
# 6575     True
# 6589     True
# 6599     True
# 6600     True
# 6605     True
# 6624     True
# 6632     True
# 6635     True
# 6637     True
# 6651     True
# 6652     True
# 6658     True
# 6659     True
# 6663     True
# 6664     True
# 6665     True
# 6667     True
# 6668     True
# 6675     True
# 6677     True
# 6678     True
# 6696     True
# 6697     True
# 6698     True
# 6699     True
# 6700     True
# 6701     True
# 6706     True
# 6708     True
# 6711     True
# 6724     True
# 6727     True
# 6742     True
# 6744     True
# 6749     True
# 6751     True
# 6753     True
# 6759     True
# 6784     True
# 6790     True
# 6936     True
# 6937     True
# 6941     True
# 6982     True
# 7040     True
# 7041     True
# 7042     True
# 7092     True
# 7093     True
# 7100     True
# 7101     True
# 7103     True
# 7104     True
# 7110     True
# 7129     True
# 7154     True
# 7161     True
# 7163     True
# 7182     True
# 7184     True
# 7198     True
# 7199     True
# 7200     True
# 7201     True
# 7202     True
# 7203     True
# 7207     True
# 7208     True
# 7209     True
# 7221     True
# 7225     True
# 7228     True
# 7234     True
# 7236     True
# 7242     True
# 7257     True
# 7270     True
# 7278     True
# 7324     True
# 7332     True
# 7334     True
# 7335     True
# 7336     True
# 7337     True
# 7338     True
# 7339     True
# 7340     True
# 7342     True
# 7343     True
# 7344     True
# 7345     True
# 7348     True
# 7349     True
# 7350     True
# 7351     True
# 7352     True
# 7355     True
# 7356     True
# 7357     True
# 7359     True
# 7363     True
# 7364     True
# 7367     True
# 7369     True
# 7370     True
# 7371     True
# 7373     True
# 7374     True
# 7375     True
# 7376     True
# 7377     True
# 7378     True
# 7382     True
# 7383     True
# 7384     True
# 7386     True
# 7387     True
# 7388     True
# 7389     True
# 7390     True
# 7391     True
# 7394     True
# 7395     True
# 7396     True
# 7397     True
# 7398     True
# 7399     True
# 7400     True
# 7402     True
# 7404     True
# 7405     True
# 7406     True
# 7407     True
# 7408     True
# 7409     True
# 7410     True
# 7413     True
# 7414     True
# 7415     True
# 7417     True
# 7423     True
# 7424     True
# 7428     True
# 7429     True
# 7431     True
# 7432     True
# 7433     True
# 7435     True
# 7437     True
# 7438     True
# 7439     True
# 7444     True
# 7445     True
# 7448     True
# 7449     True
# 7456     True
# 7459     True
# 7460     True
# 7462     True
# 7463     True
# 7464     True
# 7465     True
# 7466     True
# 7467     True
# 7468     True
# 7471     True
# 7473     True
# 7474     True
# 7475     True
# 7476     True
# 7477     True
# 7478     True
# 7479     True
# 7480     True
# 7481     True
# 7482     True
# 7483     True
# 7486     True
# 7488     True
# 7489     True
# 7490     True
# 7498     True
# 7499     True
# 7501     True
# 7503     True
# 7506     True
# 7508     True
# 7510     True
# 7513     True
# 7514     True
# 7515     True
# 7516     True
# 7519     True
# 7520     True
# 7523     True
# 7524     True
# 7525     True
# 7529     True
# 7530     True
# 7532     True
# 7534     True
# 7537     True
# 7541     True
# 7542     True
# 7543     True
# 7546     True
# 7547     True
# 7548     True
# 7549     True
# 7550     True
# 7551     True
# 7552     True
# 7553     True
# 7554     True
# 7557     True
# 7560     True
# 7562     True
# 7563     True
# 7564     True
# 7569     True
# 7570     True
# 7571     True
# 7572     True
# 7574     True
# 7575     True
# 7577     True
# 7581     True
# 7582     True
# 7584     True
# 7585     True
# 7586     True
# 7587     True
# 7588     True
# 7589     True
# 7590     True
# 7591     True
# 7593     True
# 7594     True
# 7595     True
# 7596     True
# 7597     True
# 7599     True
# 7603     True
# 7606     True
# 7607     True
# 7610     True
# 7611     True
# 7612     True
# 7613     True
# 7614     True
# 7615     True
# 7618     True
# 7619     True
# 7620     True
# 7621     True
# 7622     True
# 7623     True
# 7624     True
# 7625     True
# 7626     True
# 7627     True
# 7630     True
# 7631     True
# 7632     True
# 7633     True
# 7634     True
# 7636     True
# 7638     True
# 7640     True
# 7641     True
# 7642     True
# 7643     True
# 7644     True
# 7645     True
# 7646     True
# 7647     True
# 7648     True
# 7649     True
# 7651     True
# 7652     True
# 7654     True
# 7655     True
# 7656     True
# 7657     True
# 7658     True
# 7659     True
# 7660     True
# 7661     True
# 7665     True
# 7666     True
# 7670     True
# 7671     True
# 7672     True
# 7678     True
# 7679     True
# 7680     True
# 7681     True
# 7682     True
# 7683     True
# 7684     True
# 7685     True
# 7687     True
# 7688     True
# 7689     True
# 7690     True
# 7691     True
# 7694     True
# 7696     True
# 7697     True
# 7698     True
# 7700     True
# 7701     True
# 7703     True
# 7704     True
# 7706     True
# 7708     True
# 7709     True
# 7710     True
# 7712     True
# 7713     True
# 7714     True
# 7717     True
# 7719     True
# 7720     True
# 7721     True
# 7723     True
# 7726     True
# 7738     True
# 7746     True
# 7761     True
# 7779     True
# 7813     True
# 7816     True
# 7817     True
# 7836     True
# 7842     True
# 7855     True
# 7862     True
# 7869     True
# 7871     True
# 7872     True
# 7889     True
# 7904     True
# 7924     True
# 7928     True
# 7940     True
# 7941     True
# 7943     True
# 7945     True
# 7946     True
# 7967     True
# 7976     True
# 7983     True
# 7992     True
# 8011     True
# 8014     True
# 8021     True
# 8022     True
# 8027     True
# 8030     True
# 8033     True
# 8034     True
# 8048     True
# 8052     True
# 8053     True
# 8054     True
# 8057     True
# 8061     True
# 8062     True
# 8063     True
# 8067     True
# 8082     True
# 8099     True
# 8102     True
# 8103     True
# 8112     True
# 8141     True
# 8144     True
# 8145     True
# 8156     True
# 8158     True
# 8159     True
# 8160     True
# 8161     True
# 8171     True
# 8183     True
# 8198     True
# 8220     True
# 8229     True
# 8251     True
# 8252     True
# 8255     True
# 8260     True
# 8261     True
# 8262     True
# 8263     True
# 8264     True
# 8265     True
# 8268     True
# 8281     True
# 8290     True
# 8297     True
# 8307     True
# 8312     True
# 8315     True
# 8317     True
# 8335     True
# 8338     True
# 8339     True
# 8349     True
# 8350     True
# 8352     True
# 8360     True
# 8361     True
# 8363     True
# 8365     True
# 8367     True
# 8382     True
# 8384     True
# 8385     True
# 8387     True
# 8388     True
# 8389     True
# 8391     True
# 8397     True
# 8398     True
# 8401     True
# 8409     True
# 8410     True
# 8411     True
# 8412     True
# 8413     True
# 8414     True
# 8415     True
# 8428     True
# 8430     True
# 8432     True
# 8433     True
# 8440     True
# 8444     True
# 8445     True
# 8446     True
# 8450     True
# 8452     True
# 8454     True
# 8456     True
# 8459     True
# 8461     True
# 8463     True
# 8464     True
# 8468     True
# 8480     True
# 8486     True
# 8502     True
# 8508     True
# 8509     True
# 8511     True
# 8514     True
# 8516     True
# 8517     True
# 8518     True
# 8520     True
# 8521     True
# 8522     True
# 8540     True
# 8541     True
# 8543     True
# 8544     True
# 8556     True
# 8557     True
# 8558     True
# 8560     True
# 8566     True
# 8567     True
# 8568     True
# 8576     True
# 8584     True
# 8585     True
# 8587     True
# 8625     True
# 8655     True
# 8663     True
# 8679     True
# 8680     True
# 8688     True
# 8691     True
# 8692     True
# 8693     True
# 8702     True
# 8717     True
# 8718     True
# 8720     True
# 8721     True
# 8724     True
# 8729     True
# 8730     True
# 8731     True
# 8734     True
# 8747     True
# 8748     True
# 8754     True
# 8780     True
# 8781     True
# 8782     True
# 8784     True
# 8806     True
# 8810     True
# 8819     True
# 8820     True
# 8827     True
# 8834     True
# 8854     True
# 8855     True
# 8857     True
# 8858     True
# 8863     True
# 8865     True
# 8872     True
# 8876     True
# 8899     True
# 8904     True
# 8905     True
# 8907     True
# 8908     True
# 8909     True
# 8921     True
# 8922     True
# 8924     True
# 8930     True
# 8934     True
# 8935     True
# 8938     True
# 8941     True
# 8942     True
# 8944     True
# 8946     True
# 8948     True
# 8950     True
# 8954     True
# 8957     True
# 8959     True
# 8962     True
# 8964     True
# 8966     True
# 8967     True
# 8968     True
# 8969     True
# 8973     True
# 8974     True
# 8976     True
# 8985     True
# 8986     True
# 8987     True
# 8988     True
# 8989     True
# 8992     True
# 8994     True
# 8995     True
# 8996     True
# 8999     True
# 9000     True
# 9004     True
# 9005     True
# 9007     True
# 9009     True
# 9011     True
# 9015     True
# 9025     True
# 9026     True
# 9028     True
# 9030     True
# 9034     True
# 9036     True
# 9037     True
# 9038     True
# 9039     True
# 9047     True
# 9050     True
# 9078     True
# 9083     True
# 9085     True
# 9088     True
# 9089     True
# 9093     True
# 9098     True
# 9102     True
# 9106     True
# 9108     True
# 9115     True
# 9127     True
# 9132     True
# 9139     True
# 9152     True
# 9157     True
# 9158     True
# 9161     True
# 9162     True
# 9163     True
# 9164     True
# 9166     True
# 9167     True
# 9168     True
# 9169     True
# 9175     True
# 9185     True
# 9186     True
# 9187     True
# 9189     True
# 9190     True
# 9191     True
# 9192     True
# 9194     True
# 9197     True
# 9200     True
# 9201     True
# 9203     True
# 9206     True
# 9209     True
# 9210     True
# 9216     True
# 9217     True
# 9218     True
# 9220     True
# 9221     True
# 9222     True
# 9223     True
# 9230     True
# 9235     True
# 9246     True
# 9247     True
# 9251     True
# 9252     True
# 9256     True
# 9257     True
# 9263     True
# 9272     True
# 9276     True
# 9277     True
# 9278     True
# 9279     True
# 9280     True
# 9283     True
# 9287     True
# 9288     True
# 9290     True
# 9293     True
# 9294     True
# 9301     True
# 9303     True
# 9304     True
# 9305     True
# 9306     True
# 9308     True
# 9311     True
# 9312     True
# 9314     True
# 9318     True
# 9319     True
# 9320     True
# 9333     True
# 9342     True
# 9344     True
# 9348     True
# 9354     True
# 9355     True
# 9356     True
# 9357     True
# 9358     True
# 9364     True
# 9366     True
# 9367     True
# 9369     True
# 9373     True
# 9376     True
# 9383     True
# 9384     True
# 9387     True
# 9396     True
# 9405     True
# 9406     True
# 9407     True
# 9408     True
# 9419     True
# 9420     True
# 9421     True
# 9422     True
# 9426     True
# 9427     True
# 9429     True
# 9431     True
# 9433     True
# 9434     True
# 9437     True
# 9441     True
# 9446     True
# 9450     True
# 9457     True
# 9458     True
# 9459     True
# 9464     True
# 9466     True
# 9467     True
# 9468     True
# 9469     True
# 9474     True
# 9485     True
# 9486     True
# 9487     True
# 9489     True
# 9495     True
# 9497     True
# 9510     True
# 9511     True
# 9512     True
# 9515     True
# 9521     True
# 9525     True
# 9526     True
# 9536     True
# 9541     True
# 9543     True
# 9544     True
# 9545     True
# 9552     True
# 9554     True
# 9556     True
# 9558     True
# 9561     True
# 9567     True
# 9582     True
# 9589     True
# 9590     True
# 9592     True
# 9594     True
# 9595     True
# 9597     True
# 9605     True
# 9610     True
# 9614     True
# 9618     True
# 9619     True
# 9623     True
# 9624     True
# 9625     True
# 9626     True
# 9627     True
# 9628     True
# 9629     True
# 9639     True
# 9644     True
# 9649     True
# 9664     True
# 9670     True
# 9672     True
# 9678     True
# 9680     True
# 9681     True
# 9684     True
# 9685     True
# 9687     True
# 9690     True
# 9691     True
# 9694     True
# 9695     True
# 9700     True
# 9704     True
# 9706     True
# 9710     True
# 9715     True
# 9716     True
# 9717     True
# 9729     True
# 9740     True
# 9742     True
# 9746     True
# 9749     True
# 9750     True
# 9752     True
# 9758     True
# 9765     True
# 9774     True
# 9775     True
# 9776     True
# 9780     True
# 9784     True
# 9797     True
# 9800     True
# 9801     True
# 9802     True
# 9803     True
# 9804     True
# 9807     True
# 9808     True
# 9812     True
# 9822     True
# 9829     True
# 9834     True
# 9835     True
# 9837     True
# 9843     True
# 9848     True
# 9850     True
# 9852     True
# 9853     True
# 9854     True
# 9859     True
# 9864     True
# 9871     True
# 9896     True
# 9898     True
# 9899     True
# 9901     True
# 9910     True
# 9911     True
# 9912     True
# 9917     True
# 9918     True
# 9919     True
# 9925     True
# 9926     True
# 9929     True
# 9935     True
# 9938     True
# 9939     True
# 9941     True
# 9942     True
# 9943     True
# 9944     True
# 9945     True
# 9946     True
# 9950     True
# 9951     True
# 9952     True
# 9955     True
# 9956     True
# 9958     True
# 9959     True
# 9960     True
# 9962     True
# 9963     True
# 9964     True
# 9965     True
# 9968     True
# 9969     True
# 9970     True
# 9971     True
# 9972     True
# 9974     True
# 9975     True
# 9977     True
# 9978     True
# 9980     True
# 9981     True
# 9983     True
# 9984     True
# 9985     True
# 9986     True
# 9988     True
# 9989     True
# 9990     True
# 9994     True
# 9995     True
# 9996     True
# 9998     True
# 10000    True
# 10002    True
# 10003    True
# 10004    True
# 10007    True
# 10008    True
# 10009    True
# 10010    True
# 10011    True
# 10012    True
# 10013    True
# 10014    True
# 10015    True
# 10016    True
# 10017    True
# 10018    True
# 10020    True
# 10022    True
# 10024    True
# 10025    True
# 10027    True
# 10028    True
# 10029    True
# 10031    True
# 10032    True
# 10033    True
# 10034    True
# 10035    True
# 10037    True
# 10040    True
# 10043    True
# 10044    True
# 10045    True
# 10046    True
# 10047    True
# 10049    True
# 10050    True
# 10052    True
# 10053    True
# 10054    True
# 10056    True
# 10057    True
# 10058    True
# 10059    True
# 10063    True
# 10064    True
# 10065    True
# 10066    True
# 10070    True
# 10071    True
# 10072    True
# 10073    True
# 10074    True
# 10075    True
# 10076    True
# 10077    True
# 10078    True
# 10079    True
# 10080    True
# 10081    True
# 10083    True
# 10084    True
# 10085    True
# 10086    True
# 10087    True
# 10088    True
# 10089    True
# 10090    True
# 10091    True
# 10095    True
# 10096    True
# 10099    True
# 10100    True
# 10101    True
# 10103    True
# 10105    True
# 10109    True
# 10110    True
# 10112    True
# 10113    True
# 10118    True
# 10124    True
# 10125    True
# 10127    True
# 10129    True
# 10130    True
# 10131    True
# 10132    True
# 10135    True
# 10137    True
# 10138    True
# 10139    True
# 10140    True
# 10141    True
# 10143    True
# 10146    True
# 10147    True
# 10148    True
# 10151    True
# 10152    True
# 10153    True
# 10154    True
# 10156    True
# 10157    True
# 10158    True
# 10159    True
# 10160    True
# 10161    True
# 10164    True
# 10165    True
# 10166    True
# 10167    True
# 10169    True
# 10170    True
# 10171    True
# 10172    True
# 10173    True
# 10174    True
# 10175    True
# 10176    True
# 10177    True
# 10178    True
# 10185    True
# 10187    True
# 10188    True
# 10189    True
# 10190    True
# 10191    True
# 10192    True
# 10194    True
# 10195    True
# 10196    True
# 10197    True
# 10199    True
# 10201    True
# 10202    True
# 10203    True
# 10204    True
# 10205    True
# 10206    True
# 10207    True
# 10208    True
# 10209    True
# 10210    True
# 10211    True
# 10212    True
# 10213    True
# 10214    True
# 10215    True
# 10216    True
# 10218    True
# 10219    True
# 10220    True
# 10221    True
# 10222    True
# 10223    True
# 10224    True
# 10226    True
# 10227    True
# 10228    True
# 10229    True
# 10233    True
# 10234    True
# 10238    True
# 10240    True
# 10241    True
# 10245    True
# 10246    True
# 10249    True
# 10250    True
# 10251    True
# 10253    True
# 10254    True
# 10256    True
# 10257    True
# 10259    True
# 10260    True
# 10262    True
# 10263    True
# 10264    True
# 10265    True
# 10266    True
# 10268    True
# 10271    True
# 10275    True
# 10277    True
# 10279    True
# 10280    True
# 10281    True
# 10282    True
# 10284    True
# 10286    True
# 10287    True
# 10289    True
# 10291    True
# 10293    True
# 10294    True
# 10297    True
# 10300    True
# 10303    True
# 10304    True
# 10305    True
# 10306    True
# 10307    True
# 10310    True
# 10312    True
# 10313    True
# 10314    True
# 10315    True
# 10316    True
# 10318    True
# 10319    True
# 10325    True
# 10326    True
# 10328    True
# 10331    True
# 10332    True
# 10333    True
# 10346    True
# 10354    True
# 10355    True
# 10356    True
# 10357    True
# 10358    True
# 10359    True
# 10360    True
# 10363    True
# 10365    True
# 10374    True
# 10379    True
# 10380    True
# 10387    True
# 10401    True
# 10402    True
# 10410    True
# 10412    True
# 10423    True
# 10425    True
# 10426    True
# 10448    True
# 10452    True
# 10453    True
# 10458    True
# 10459    True
# 10460    True
# 10466    True
# 10469    True
# 10470    True
# 10481    True
# 10493    True
# 10500    True
# 10501    True
# 10502    True
# 10505    True
# 10508    True
# 10512    True
# 10513    True
# 10525    True
# 10527    True
# 10528    True
# 10529    True
# 10530    True
# 10531    True
# 10544    True
# 10557    True
# 10558    True
# 10561    True
# 10572    True
# 10593    True
# 10595    True
# 10598    True
# 10609    True
# 10610    True
# 10619    True
# 10633    True
# 10637    True
# 10639    True
# 10640    True
# 10648    True
# 10650    True
# 10651    True
# 10655    True
# 10660    True
# 10662    True
# 10667    True
# 10674    True
# 10689    True
# 10694    True
# 10696    True
# 10698    True
# 10702    True
# 10703    True
# 10705    True
# 10709    True
# 10732    True
# 10737    True
# 10738    True
# 10743    True
# 10750    True
# 10752    True
# 10753    True
# 10759    True
# 10765    True
# 10766    True
# 10772    True
# 10775    True
# 10776    True
# 10777    True
# 10779    True
# 10784    True
# 10795    True
# 10799    True
# 10800    True
# 10801    True
# 10829    True
# 10842    True
# 10846    True
# 10848    True
# 10860    True
# 10861    True
# 10864    True
# 10869    True
# 10870    True
# 10875    True
# 10878    True
# 10879    True
# 10882    True
# 10891    True
# 10892    True
# 10903    True
# 10908    True
# 10912    True
# 10916    True
# 10923    True
# 10933    True
# 10935    True
# 10937    True
# 10944    True
# 10965    True
# 10968    True
# 10969    True
# 10970    True
# 10972    True
# 10982    True
# 10996    True
# 11010    True
# 11015    True
# 11026    True
# 11029    True
# 11052    True
# 11066    True
# 11067    True
# 11068    True
# 11070    True
# 11073    True
# 11087    True
# 11096    True
# 11097    True
# 11098    True
# 11102    True
# 11108    True
# 11120    True
# 11125    True
# 11130    True
# 11135    True
# 11138    True
# 11139    True
# 11147    True
# 11149    True
# 11150    True
# 11151    True
# 11152    True
# 11154    True
# 11155    True
# 11159    True
# 11166    True
# 11167    True
# 11170    True
# 11173    True
# 11184    True
# 11186    True
# 11187    True
# 11190    True
# 11191    True
# 11194    True
# 11196    True
# 11198    True
# 11199    True
# 11205    True
# 11210    True
# 11214    True
# 11226    True
# 11231    True
# 11236    True
# 11241    True
# 11243    True
# 11244    True
# 11247    True
# 11257    True
# 11258    True
# 11260    True
# 11264    True
# 11281    True
# 11289    True
# 11296    True
# 11301    True
# 11308    True
# 11311    True
# 11317    True
# 11324    True
# 11326    True
# 11331    True
# 11334    True
# 11356    True
# 11359    True
# 11370    True
# 11372    True
# 11373    True
# 11375    True
# 11376    True
# 11377    True
# 11378    True
# 11379    True
# 11380    True
# 11381    True
# 11382    True
# 11389    True
# 11391    True
# 11392    True
# 11406    True
# 11407    True
# 11418    True
# 11419    True
# 11429    True
# 11451    True
# 11455    True
# 11456    True
# 11457    True
# 11460    True
# 11463    True
# 11466    True
# 11468    True
# 11476    True
# 11477    True
# 11479    True
# 11481    True
# 11482    True
# 11484    True
# 11485    True
# 11486    True
# 11489    True
# 11490    True
# 11491    True
# 11498    True
# 11504    True
# 11506    True
# 11507    True
# 11511    True
# 11513    True
# 11515    True
# 11529    True
# 11531    True
# 11535    True
# 11536    True
# 11550    True
# 11555    True
# 11564    True
# 11569    True
# 11571    True
# 11576    True
# 11578    True
# 11580    True
# 11592    True
# 11594    True
# 11595    True
# 11597    True
# 11611    True
# 11612    True
# 11615    True
# 11616    True
# 11619    True
# 11620    True
# 11621    True
# 11623    True
# 11626    True
# 11627    True
# 11629    True
# 11632    True
# 11637    True
# 11645    True
# 11648    True
# 11656    True
# 11657    True
# 11658    True
# 11659    True
# 11661    True
# 11667    True
# 11668    True
# 11671    True
# 11672    True
# 11673    True
# 11674    True
# 11675    True
# 11677    True
# 11688    True
# 11704    True
# 11707    True
# 11709    True
# 11712    True
# 11714    True
# 11715    True
# 11716    True
# 11717    True
# 11718    True
# 11719    True
# 11720    True
# 11722    True
# 11724    True
# 11725    True
# 11726    True
# 11729    True
# 11730    True
# 11733    True
# 11735    True
# 11736    True
# 11741    True
# 11742    True
# 11747    True
# 11748    True
# 11752    True
# 11757    True
# 11773    True
# 11784    True
# 11791    True
# 11796    True
# 11800    True
# 11802    True
# 11805    True
# 11806    True
# 11807    True
# 11811    True
# 11813    True
# 11819    True
# 11823    True
# 11826    True
# 11834    True
# 11840    True
# 11844    True
# 11845    True
# 11847    True
# 11849    True
# 11851    True
# 11852    True
# 11853    True
# 11855    True
# 11859    True
# 11878    True
# 11891    True
# 11905    True
# 11910    True
# 11916    True
# 11917    True
# 11920    True
# 11923    True
# 11925    True
# 11927    True
# 11928    True
# 11935    True
# 11936    True
# 11937    True
# 11939    True
# 11942    True
# 11943    True
# 11944    True
# 11945    True
# 11960    True
# 11964    True
# 11970    True
# 11973    True
# 11976    True
# 11984    True
# 11988    True
# 11994    True
# 12001    True
# 12010    True
# 12011    True
# 12012    True
# 12013    True
# 12016    True
# 12020    True
# 12022    True
# 12023    True
# 12024    True
# 12031    True
# 12036    True
# 12039    True
# 12049    True
# 12050    True
# 12062    True
# 12071    True
# 12073    True
# 12075    True
# 12079    True
# 12087    True
# 12092    True
# 12094    True
# 12095    True
# 12099    True
# 12105    True
# 12111    True
# 12113    True
# 12116    True
# 12125    True
# 12126    True
# 12127    True
# 12132    True
# 12134    True
# 12136    True
# 12139    True
# 12141    True
# 12143    True
# 12155    True
# 12161    True
# 12162    True
# 12163    True
# 12164    True
# 12165    True
# 12172    True
# 12175    True
# 12178    True
# 12180    True
# 12181    True
# 12183    True
# 12184    True
# 12187    True
# 12189    True
# 12192    True
# 12195    True
# 12204    True
# 12216    True
# 12227    True
# 12234    True
# 12235    True
# 12238    True
# 12239    True
# 12241    True
# 12244    True
# 12245    True
# 12253    True
# 12254    True
# 12257    True
# 12260    True
# 12261    True
# 12263    True
# 12287    True
# 12288    True
# 12292    True
# 12293    True
# 12303    True
# 12305    True
# 12306    True
# 12307    True
# 12308    True
# 12315    True
# 12318    True
# 12333    True
# 12339    True
# 12341    True
# 12344    True
# 12355    True
# 12362    True
# 12364    True
# 12383    True
# 12384    True
# 12392    True
# 12394    True
# 12401    True
# 12410    True
# 12415    True
# 12427    True
# 12439    True
# 12440    True
# 12445    True
# 12446    True
# 12447    True
# 12455    True
# 12466    True
# 12468    True
# 12469    True
# 12471    True
# 12472    True
# 12474    True
# 12475    True
# 12476    True
# 12477    True
# 12478    True
# 12480    True
# 12482    True
# 12491    True
# 12501    True
# 12504    True
# 12514    True
# 12517    True
# 12522    True
# 12523    True
# 12525    True
# 12529    True
# 12543    True
# 12544    True
# 12556    True
# 12563    True
# 12572    True
# 12575    True
# 12576    True
# 12578    True
# 12580    True
# 12581    True
# 12582    True
# 12590    True
# 12592    True
# 12634    True
# 12635    True
# 12637    True
# 12639    True
# 12640    True
# 12642    True
# 12653    True
# 12654    True
# 12663    True
# 12664    True
# 12668    True
# 12678    True
# 12687    True
# 12695    True
# 12699    True
# 12701    True
# 12704    True
# 12719    True
# 12729    True
# 12730    True
# 12731    True
# 12733    True
# 12734    True
# 12735    True
# 12741    True
# 12743    True
# 12744    True
# 12748    True
# 12749    True
# 12750    True
# 12752    True
# 12757    True
# 12758    True
# 12765    True
# 12766    True
# 12767    True
# 12772    True
# 12773    True
# 12778    True
# 12782    True
# 12785    True
# 12786    True
# 12799    True
# 12815    True
# 12823    True
# 12837    True
# 12838    True
# 12844    True
# 12845    True
# 12854    True
# 12859    True
# 12867    True
# 12868    True
# 12869    True
# 12870    True
# 12871    True
# 12873    True
# 12874    True
# 12875    True
# 12876    True
# 12877    True
# 12878    True
# 12882    True
# 12884    True
# 12889    True
# 12892    True
# 12902    True
# 12906    True
# 12907    True
# 12908    True
# 12909    True
# 12912    True
# 12918    True
# 12922    True
# 12929    True
# 12930    True
# 12935    True
# 12939    True
# 12941    True
# 12942    True
# 12954    True
# 12955    True
# 12962    True
# 12963    True
# 12969    True
# 12974    True
# 12978    True
# 13002    True
# 13003    True
# 13004    True
# 13005    True
# 13007    True
# 13008    True
# 13009    True
# 13010    True
# 13011    True
# 13027    True
# 13028    True
# 13040    True
# 13042    True
# 13047    True
# 13048    True
# 13056    True
# 13061    True
# 13063    True
# 13067    True
# 13070    True
# 13080    True
# 13083    True
# 13087    True
# 13092    True
# 13098    True
# 13099    True
# 13100    True
# 13105    True
# 13117    True
# 13118    True
# 13119    True
# 13120    True
# 13121    True
# 13122    True
# 13123    True
# 13124    True
# 13127    True
# 13133    True
# 13135    True
# 13140    True
# 13156    True
# 13157    True
# 13168    True
# 13172    True
# 13185    True
# 13186    True
# 13187    True
# 13191    True
# 13194    True
# 13195    True
# 13201    True
# 13202    True
# 13203    True
# 13207    True
# 13208    True
# 13209    True
# 13218    True
# 13219    True
# 13227    True
# 13229    True
# 13233    True
# 13237    True
# 13240    True
# 13243    True
# 13247    True
# 13259    True
# 13270    True
# 13274    True
# 13280    True
# 13281    True
# 13283    True
# 13296    True
# 13298    True
# 13305    True
# 13307    True
# 13309    True
# 13310    True
# 13314    True
# 13315    True
# 13317    True
# 13323    True
# 13331    True
# 13332    True
# 13333    True
# 13334    True
# 13339    True
# 13341    True
# 13342    True
# 13343    True
# 13351    True
# 13366    True
# 13371    True
# 13382    True
# 13386    True
# 13399    True
# 13403    True
# 13404    True
# 13405    True
# 13409    True
# 13414    True
# 13433    True
# 13435    True
# 13436    True
# 13437    True
# 13438    True
# 13439    True
# 13440    True
# 13442    True
# 13443    True
# 13444    True
# 13455    True
# 13458    True
# 13459    True
# 13467    True
# 13479    True
# 13487    True
# 13507    True
# 13514    True
# 13517    True
# 13518    True
# 13523    True
# 13524    True
# 13530    True
# 13533    True
# 13534    True
# 13540    True
# 13542    True
# 13544    True
# 13547    True
# 13580    True
# 13581    True
# 13583    True
# 13585    True
# 13587    True
# 13592    True
# 13596    True
# 13598    True
# 13602    True
# 13605    True
# 13606    True
# 13607    True
# 13609    True
# 13614    True
# 13615    True
# 13629    True
# 13633    True
# 13635    True
# 13636    True
# 13639    True
# 13640    True
# 13645    True
# 13652    True
# 13655    True
# 13656    True
# 13659    True
# 13660    True
# 13666    True
# 13668    True
# 13670    True
# 13672    True
# 13673    True
# 13675    True
# 13676    True
# 13680    True
# 13684    True
# 13686    True
# 13713    True
# 13718    True
# 13721    True
# 13725    True
# 13728    True
# 13729    True
# 13731    True
# 13732    True
# 13733    True
# 13735    True
# 13740    True
# 13742    True
# 13745    True
# 13747    True
# 13749    True
# 13755    True
# 13758    True
# 13761    True
# 13770    True
# 13771    True
# 13776    True
# 13777    True
# 13786    True
# 13791    True
# 13794    True
# 13795    True
# ...
# 31550    True
# 31552    True
# 31554    True
# 31555    True
# 31556    True
# 31557    True
# 31559    True
# 31561    True
# 31562    True
# 31564    True
# 31567    True
# 31568    True
# 31571    True
# 31572    True
# 31573    True
# 31574    True
# 31576    True
# 31577    True
# 31578    True
# 31579    True
# 31581    True
# 31582    True
# 31583    True
# 31585    True
# 31588    True
# 31589    True
# 31590    True
# 31591    True
# 31595    True
# 31596    True
# 31597    True
# 31598    True
# 31599    True
# 31601    True
# 31602    True
# 31603    True
# 31604    True
# 31605    True
# 31606    True
# 31607    True
# 31608    True
# 31609    True
# 31610    True
# 31611    True
# 31612    True
# 31614    True
# 31615    True
# 31616    True
# 31617    True
# 31618    True
# 31619    True
# 31620    True
# 31623    True
# 31626    True
# 31628    True
# 31629    True
# 31631    True
# 31633    True
# 31634    True
# 31635    True
# 31636    True
# 31637    True
# 31638    True
# 31639    True
# 31640    True
# 31642    True
# 31643    True
# 31644    True
# 31645    True
# 31646    True
# 31647    True
# 31648    True
# 31649    True
# 31650    True
# 31651    True
# 31652    True
# 31654    True
# 31655    True
# 31656    True
# 31657    True
# 31658    True
# 31660    True
# 31661    True
# 31662    True
# 31663    True
# 31664    True
# 31665    True
# 31666    True
# 31667    True
# 31668    True
# 31669    True
# 31670    True
# 31671    True
# 31672    True
# 31673    True
# 31674    True
# 31675    True
# 31676    True
# 31677    True
# 31678    True
# 31679    True
# 31680    True
# 31681    True
# 31682    True
# 31683    True
# 31684    True
# 31685    True
# 31686    True
# 31687    True
# 31688    True
# 31689    True
# 31690    True
# 31692    True
# 31693    True
# 31697    True
# 31700    True
# 31702    True
# 31705    True
# 31709    True
# 31710    True
# 31711    True
# 31712    True
# 31715    True
# 31718    True
# 31719    True
# 31720    True
# 31723    True
# 31724    True
# 31727    True
# 31734    True
# 31755    True
# 31760    True
# 31763    True
# 31767    True
# 31769    True
# 31777    True
# 31778    True
# 31780    True
# 31800    True
# 31802    True
# 31804    True
# 31809    True
# 31812    True
# 31820    True
# 31821    True
# 31823    True
# 31827    True
# 31828    True
# 31838    True
# 31843    True
# 31844    True
# 31845    True
# 31846    True
# 31848    True
# 31854    True
# 31855    True
# 31856    True
# 31857    True
# 31858    True
# 31865    True
# 31868    True
# 31874    True
# 31875    True
# 31877    True
# 31878    True
# 31880    True
# 31881    True
# 31887    True
# 31888    True
# 31889    True
# 31892    True
# 31893    True
# 31894    True
# 31905    True
# 31914    True
# 31915    True
# 31916    True
# 31918    True
# 31928    True
# 31929    True
# 31933    True
# 31935    True
# 31936    True
# 31949    True
# 31957    True
# 31958    True
# 31959    True
# 31980    True
# 31981    True
# 31983    True
# 31986    True
# 31990    True
# 31991    True
# 31992    True
# 31993    True
# 31994    True
# 31996    True
# 31998    True
# 31999    True
# 32000    True
# 32006    True
# 32007    True
# 32022    True
# 32024    True
# 32025    True
# 32032    True
# 32037    True
# 32038    True
# 32039    True
# 32041    True
# 32045    True
# 32049    True
# 32051    True
# 32052    True
# 32053    True
# 32058    True
# 32061    True
# 32062    True
# 32069    True
# 32070    True
# 32072    True
# 32075    True
# 32077    True
# 32084    True
# 32109    True
# 32111    True
# 32113    True
# 32115    True
# 32119    True
# 32124    True
# 32125    True
# 32126    True
# 32127    True
# 32128    True
# 32129    True
# 32136    True
# 32137    True
# 32138    True
# 32139    True
# 32145    True
# 32148    True
# 32149    True
# 32162    True
# 32165    True
# 32166    True
# 32168    True
# 32171    True
# 32172    True
# 32173    True
# 32174    True
# 32175    True
# 32180    True
# 32184    True
# 32195    True
# 32203    True
# 32204    True
# 32207    True
# 32212    True
# 32215    True
# 32220    True
# 32226    True
# 32227    True
# 32228    True
# 32232    True
# 32234    True
# 32235    True
# 32238    True
# 32248    True
# 32249    True
# 32250    True
# 32251    True
# 32252    True
# 32259    True
# 32261    True
# 32270    True
# 32277    True
# 32278    True
# 32289    True
# 32304    True
# 32312    True
# 32313    True
# 32315    True
# 32319    True
# 32326    True
# 32329    True
# 32332    True
# 32336    True
# 32338    True
# 32339    True
# 32340    True
# 32341    True
# 32351    True
# 32356    True
# 32359    True
# 32363    True
# 32377    True
# 32382    True
# 32391    True
# 32392    True
# 32393    True
# 32398    True
# 32405    True
# 32406    True
# 32409    True
# 32420    True
# 32421    True
# 32423    True
# 32425    True
# 32427    True
# 32428    True
# 32430    True
# 32442    True
# 32444    True
# 32445    True
# 32451    True
# 32456    True
# 32462    True
# 32471    True
# 32479    True
# 32486    True
# 32511    True
# 32512    True
# 32514    True
# 32515    True
# 32516    True
# 32517    True
# 32519    True
# 32524    True
# 32526    True
# 32527    True
# 32529    True
# 32530    True
# 32531    True
# 32532    True
# 32533    True
# 32551    True
# 32558    True
# 32559    True
# 32563    True
# 32568    True
# 32579    True
# 32580    True
# 32581    True
# 32582    True
# 32589    True
# 32590    True
# 32591    True
# 32598    True
# 32600    True
# 32601    True
# 32606    True
# 32614    True
# 32619    True
# 32620    True
# 32621    True
# 32631    True
# 32634    True
# 32635    True
# 32636    True
# 32643    True
# 32644    True
# 32647    True
# 32655    True
# 32660    True
# 32662    True
# 32663    True
# 32668    True
# 32670    True
# 32671    True
# 32679    True
# 32686    True
# 32692    True
# 32694    True
# 32696    True
# 32699    True
# 32704    True
# 32707    True
# 32719    True
# 32720    True
# 32721    True
# 32722    True
# 32726    True
# 32727    True
# 32728    True
# 32729    True
# 32730    True
# 32734    True
# 32736    True
# 32743    True
# 32744    True
# 32764    True
# 32770    True
# 32786    True
# 32788    True
# 32795    True
# 32797    True
# 32798    True
# 32807    True
# 32809    True
# 32812    True
# 32822    True
# 32847    True
# 32848    True
# 32850    True
# 32852    True
# 32853    True
# 32872    True
# 32874    True
# 32877    True
# 32878    True
# 32881    True
# 32886    True
# 32897    True
# 32898    True
# 32904    True
# 32919    True
# 32927    True
# 32930    True
# 32932    True
# 32934    True
# 32941    True
# 32953    True
# 32954    True
# 32964    True
# 32965    True
# 32969    True
# 32970    True
# 32971    True
# 32972    True
# 32974    True
# 32975    True
# 32978    True
# 32982    True
# 32985    True
# 32992    True
# 33003    True
# 33006    True
# 33014    True
# 33026    True
# 33041    True
# 33047    True
# 33050    True
# 33052    True
# 33054    True
# 33055    True
# 33059    True
# 33060    True
# 33063    True
# 33064    True
# 33065    True
# 33067    True
# 33068    True
# 33072    True
# 33080    True
# 33081    True
# 33085    True
# 33093    True
# 33100    True
# 33110    True
# 33112    True
# 33121    True
# 33129    True
# 33133    True
# 33145    True
# 33146    True
# 33148    True
# 33161    True
# 33162    True
# 33177    True
# 33188    True
# 33192    True
# 33195    True
# 33196    True
# 33197    True
# 33198    True
# 33201    True
# 33203    True
# 33209    True
# 33210    True
# 33211    True
# 33220    True
# 33221    True
# 33224    True
# 33225    True
# 33227    True
# 33229    True
# 33231    True
# 33232    True
# 33237    True
# 33238    True
# 33247    True
# 33255    True
# 33259    True
# 33260    True
# 33261    True
# 33265    True
# 33273    True
# 33278    True
# 33290    True
# 33292    True
# 33295    True
# 33298    True
# 33300    True
# 33303    True
# 33304    True
# 33305    True
# 33307    True
# 33309    True
# 33323    True
# 33327    True
# 33337    True
# 33341    True
# 33349    True
# 33361    True
# 33364    True
# 33377    True
# 33384    True
# 33391    True
# 33406    True
# 33412    True
# 33422    True
# 33424    True
# 33426    True
# 33427    True
# 33428    True
# 33429    True
# 33430    True
# 33433    True
# 33434    True
# 33437    True
# 33439    True
# 33441    True
# 33443    True
# 33445    True
# 33449    True
# 33455    True
# 33464    True
# 33472    True
# 33491    True
# 33495    True
# 33511    True
# 33522    True
# 33527    True
# 33546    True
# 33551    True
# 33554    True
# 33555    True
# 33557    True
# 33558    True
# 33559    True
# 33580    True
# 33582    True
# 33584    True
# 33587    True
# 33605    True
# 33606    True
# 33607    True
# 33613    True
# 33614    True
# 33624    True
# 33627    True
# 33628    True
# 33629    True
# 33630    True
# 33638    True
# 33639    True
# 33640    True
# 33648    True
# 33650    True
# 33665    True
# 33713    True
# 33719    True
# 33720    True
# 33721    True
# 33723    True
# 33725    True
# 33728    True
# 33729    True
# 33730    True
# 33740    True
# 33742    True
# 33745    True
# 33752    True
# 33754    True
# 33759    True
# 33762    True
# 33763    True
# 33765    True
# 33767    True
# 33774    True
# 33785    True
# 33787    True
# 33796    True
# 33797    True
# 33801    True
# 33806    True
# 33808    True
# 33809    True
# 33817    True
# 33822    True
# 33826    True
# 33831    True
# 33837    True
# 33849    True
# 33850    True
# 33851    True
# 33852    True
# 33853    True
# 33855    True
# 33856    True
# 33857    True
# 33858    True
# 33864    True
# 33866    True
# 33869    True
# 33870    True
# 33873    True
# 33874    True
# 33875    True
# 33876    True
# 33892    True
# 33902    True
# 33913    True
# 33917    True
# 33921    True
# 33922    True
# 33923    True
# 33929    True
# 33948    True
# 33953    True
# 33958    True
# 33965    True
# 33973    True
# 33975    True
# 33976    True
# 33979    True
# 33980    True
# 33981    True
# 33982    True
# 33983    True
# 33984    True
# 33988    True
# 33989    True
# 33990    True
# 33992    True
# 33994    True
# 33996    True
# 33997    True
# 33999    True
# 34002    True
# 34003    True
# 34009    True
# 34016    True
# 34018    True
# 34020    True
# 34026    True
# 34027    True
# 34028    True
# 34029    True
# 34030    True
# 34031    True
# 34045    True
# 34047    True
# 34050    True
# 34052    True
# 34053    True
# 34054    True
# 34057    True
# 34059    True
# 34060    True
# 34080    True
# 34087    True
# 34088    True
# 34092    True
# 34095    True
# 34101    True
# 34104    True
# 34105    True
# 34106    True
# 34107    True
# 34108    True
# 34109    True
# 34111    True
# 34113    True
# 34121    True
# 34124    True
# 34127    True
# 34129    True
# 34132    True
# 34135    True
# 34139    True
# 34140    True
# 34143    True
# 34146    True
# 34157    True
# 34160    True
# 34161    True
# 34177    True
# 34178    True
# 34181    True
# 34191    True
# 34193    True
# 34194    True
# 34205    True
# 34206    True
# 34207    True
# 34211    True
# 34212    True
# 34214    True
# 34219    True
# 34221    True
# 34222    True
# 34223    True
# 34224    True
# 34225    True
# 34227    True
# 34230    True
# 34235    True
# 34236    True
# 34240    True
# 34243    True
# 34245    True
# 34247    True
# 34248    True
# 34249    True
# 34250    True
# 34261    True
# 34273    True
# 34287    True
# 34291    True
# 34300    True
# 34301    True
# 34303    True
# 34307    True
# 34318    True
# 34320    True
# 34321    True
# 34322    True
# 34328    True
# 34329    True
# 34332    True
# 34333    True
# 34340    True
# 34356    True
# 34360    True
# 34361    True
# 34362    True
# 34364    True
# 34365    True
# 34367    True
# 34396    True
# 34400    True
# 34404    True
# 34413    True
# 34415    True
# 34420    True
# 34430    True
# 34437    True
# 34448    True
# 34452    True
# 34453    True
# 34460    True
# 34461    True
# 34462    True
# 34463    True
# 34464    True
# 34465    True
# 34466    True
# 34471    True
# 34477    True
# 34498    True
# 34499    True
# 34500    True
# 34503    True
# 34505    True
# 34506    True
# 34510    True
# 34512    True
# 34514    True
# 34525    True
# 34526    True
# 34536    True
# 34539    True
# 34540    True
# 34541    True
# 34542    True
# 34545    True
# 34548    True
# 34552    True
# 34560    True
# 34561    True
# 34565    True
# 34566    True
# 34568    True
# 34569    True
# 34572    True
# 34574    True
# 34576    True
# 34578    True
# 34591    True
# 34600    True
# 34601    True
# 34602    True
# 34610    True
# 34611    True
# 34616    True
# 34618    True
# 34619    True
# 34628    True
# 34629    True
# 34633    True
# 34634    True
# 34663    True
# 34670    True
# 34673    True
# 34677    True
# 34681    True
# 34704    True
# 34705    True
# 34706    True
# 34707    True
# 34713    True
# 34716    True
# 34718    True
# 34721    True
# 34724    True
# 34730    True
# 34731    True
# 34732    True
# 34738    True
# 34740    True
# 34742    True
# 34743    True
# 34750    True
# 34751    True
# 34769    True
# 34788    True
# 34792    True
# 34793    True
# 34798    True
# 34799    True
# 34804    True
# 34807    True
# 34808    True
# 34821    True
# 34822    True
# 34828    True
# 34858    True
# 34859    True
# 34860    True
# 34865    True
# 34866    True
# 34869    True
# 34881    True
# 34893    True
# 34902    True
# 34905    True
# 34907    True
# 34912    True
# 34914    True
# 34926    True
# 34936    True
# 34938    True
# 34966    True
# 34970    True
# 34977    True
# 34979    True
# 34986    True
# 34992    True
# 35004    True
# 35005    True
# 35007    True
# 35008    True
# 35009    True
# 35011    True
# 35014    True
# 35015    True
# 35016    True
# 35027    True
# 35029    True
# 35030    True
# 35044    True
# 35053    True
# 35058    True
# 35059    True
# 35060    True
# 35066    True
# 35072    True
# 35080    True
# 35082    True
# 35083    True
# 35088    True
# 35089    True
# 35090    True
# 35100    True
# 35107    True
# 35110    True
# 35111    True
# 35112    True
# 35113    True
# 35120    True
# 35121    True
# 35122    True
# 35123    True
# 35124    True
# 35125    True
# 35126    True
# 35130    True
# 35135    True
# 35142    True
# 35144    True
# 35153    True
# 35154    True
# 35155    True
# 35156    True
# 35157    True
# 35159    True
# 35161    True
# 35169    True
# 35170    True
# 35171    True
# 35181    True
# 35182    True
# 35183    True
# 35187    True
# 35196    True
# 35200    True
# 35204    True
# 35205    True
# 35213    True
# 35214    True
# 35217    True
# 35227    True
# 35244    True
# 35245    True
# 35247    True
# 35255    True
# 35263    True
# 35266    True
# 35267    True
# 35272    True
# 35277    True
# 35278    True
# 35280    True
# 35282    True
# 35290    True
# 35291    True
# 35293    True
# 35294    True
# 35302    True
# 35304    True
# 35327    True
# 35332    True
# 35333    True
# 35334    True
# 35342    True
# 35357    True
# 35358    True
# 35363    True
# 35385    True
# 35395    True
# 35401    True
# 35408    True
# 35416    True
# 35418    True
# 35424    True
# 35427    True
# 35428    True
# 35433    True
# 35434    True
# 35439    True
# 35440    True
# 35442    True
# 35443    True
# 35445    True
# 35446    True
# 35447    True
# 35461    True
# 35468    True
# 35469    True
# 35472    True
# 35477    True
# 35478    True
# 35480    True
# 35482    True
# 35483    True
# 35484    True
# 35497    True
# 35499    True
# 35504    True
# 35506    True
# 35507    True
# 35511    True
# 35513    True
# 35514    True
# 35515    True
# 35516    True
# 35517    True
# 35519    True
# 35520    True
# 35521    True
# 35525    True
# 35529    True
# 35533    True
# 35537    True
# 35539    True
# 35561    True
# 35564    True
# 35565    True
# 35566    True
# 35568    True
# 35571    True
# 35576    True
# 35577    True
# 35583    True
# 35588    True
# 35589    True
# 35592    True
# 35611    True
# 35613    True
# 35629    True
# 35630    True
# 35632    True
# 35638    True
# 35640    True
# 35642    True
# 35643    True
# 35644    True
# 35645    True
# 35646    True
# 35648    True
# 35654    True
# 35655    True
# 35656    True
# 35658    True
# 35660    True
# 35674    True
# 35690    True
# 35696    True
# 35698    True
# 35703    True
# 35705    True
# 35706    True
# 35709    True
# 35720    True
# 35723    True
# 35726    True
# 35729    True
# 35731    True
# 35732    True
# 35733    True
# 35736    True
# 35737    True
# 35738    True
# 35747    True
# 35750    True
# 35762    True
# 35765    True
# 35781    True
# 35792    True
# 35793    True
# 35794    True
# 35798    True
# 35813    True
# 35822    True
# 35826    True
# 35827    True
# 35832    True
# 35833    True
# 35837    True
# 35838    True
# 35839    True
# 35840    True
# 35842    True
# 35843    True
# 35848    True
# 35860    True
# 35862    True
# 35864    True
# 35865    True
# 35867    True
# 35869    True
# 35875    True
# 35876    True
# 35877    True
# 35879    True
# 35886    True
# 35888    True
# 35890    True
# 35894    True
# 35895    True
# 35897    True
# 35905    True
# 35906    True
# 35913    True
# 35915    True
# 35930    True
# 35931    True
# 35933    True
# 35936    True
# 35937    True
# 35938    True
# 35939    True
# 35941    True
# 35942    True
# 35943    True
# 35944    True
# 35945    True
# 35948    True
# 35953    True
# 35958    True
# 35968    True
# 35986    True
# 35991    True
# 35992    True
# 36004    True
# 36006    True
# 36017    True
# 36024    True
# 36030    True
# 36031    True
# 36039    True
# 36040    True
# 36043    True
# 36044    True
# 36054    True
# 36059    True
# 36064    True
# 36070    True
# 36074    True
# 36075    True
# 36076    True
# 36079    True
# 36091    True
# 36101    True
# 36134    True
# 36224    True
# 36311    True
# 36330    True
# 36336    True
# 36363    True
# 36373    True
# dtype: bool

# %% [markdown]
# <br>

# %% [markdown]
# #### **Observation regarding `df.duplicated()`**
# - Duplicate records are removed from the dataset using `df.drop_duplicates()`.
# - A subsequent duplicate check using `df.duplicated()` returns an empty result.
# - This confirms that **no duplicate rows** remain in the dataset after the removal step.

# %%
# Remove duplicate rows
df.drop_duplicates(inplace=True)

# %%
# Confirm no duplicate records remain
duplicates = df.duplicated()
duplicates[duplicates==True]
# Out:
# Series([], dtype: bool)

# %% [markdown]
# <br>

# %% [markdown]
# #### **Observation regarding missing values | (Post-check)**
# - After removing duplicate records, the amount of missing data decreased slightly, reflecting a decrease in the size of the dataset.

# %%
# Recheck missing values after removing duplicate records
missing_values = df.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100

missing_df = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage (%)': missing_percentage
}).sort_values(by='Missing Values', ascending=False)

print(missing_df)
# Out:
#                      Missing Values  Percentage (%)
# OCCUPATION_TYPE                8568       30.689877
# EMPLOYED_DATE                  4663       16.702486
# FLAG_OWN_CAR                      0        0.000000
# CODE_GENDER                       0        0.000000
# FLAG_OWN_REALTY                   0        0.000000
# CNT_CHILDREN                      0        0.000000
# NAME_EDUCATION_TYPE               0        0.000000
# NAME_FAMILY_STATUS                0        0.000000
# AMT_INCOME_TOTAL                  0        0.000000
# NAME_INCOME_TYPE                  0        0.000000
# BIRTHDAY                          0        0.000000
# NAME_HOUSING_TYPE                 0        0.000000
# FLAG_WORK_PHONE                   0        0.000000
# FLAG_MOBIL                        0        0.000000
# FLAG_PHONE                        0        0.000000
# FLAG_EMAIL                        0        0.000000
# CNT_FAM_MEMBERS                   0        0.000000
# SCORE                             0        0.000000

# %% [markdown]
# <br>

# %% [markdown]
# #### **Observation regarding `sns.pairplot(df)` | (Post-check)**
# - The pairwise relationships between features remain visually consistent after duplicate removal.
# - No new patterns or strong linear relationships are observed compared to the pre-check pairplot.

# %%
# Plot pairwise relationships using seaborn pairplot after removing duplicate records
sns.pairplot(df)
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# #### **Observation regarding `SCORE`| (Post-check)**
# - The distribution of the `SCORE` variable remains **non-uniform**, with values still concentrated in the higher score range.
# - The distribution continues to be **left-skewed**, showing a long tail toward lower score values.

# %%
# Plot the distribution of the credit score to examine its spread, skewness, and overall shape
sns.histplot(df['SCORE'], kde=True)
plt.title('Distribution of Credit Score')
plt.show()
